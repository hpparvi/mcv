# %% [markdown]
# # Multicolour planet candidate validation
# ## Ground-based photometry and TESS

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Import and initialize MultiColour Validation LPF
#
# The `muscat2ta.MCVLPF` (MultiColour Validation LPF) class takes care of the colour validation model optimisation and MCMC sampling.

# %%
from mcv import MCVLPF

# %%
lpf = MCVLPF(3629.01)
# Out:
# Fetching data from https://exofop.ipac.caltech.edu/tess/download_toi.php?output=pipe&toi=3629.01

# %%
lpf.ps
# Out:
# [  0 |G| tc             N(μ = 2458784.25613, σ = 0.0018838)      [    -inf ..      inf],
#    1 |G| p              N(μ = 3.9381727, σ = 0.0012166)          [    0.00 ..      inf],
#    2 |G| rho            U(a = 1, b = 35)                         [    0.00 ..      inf],
#    3 |G| b              U(a = 0.0, b = 1.0)                      [    0.00 ..     1.00],
#    4 |P| k2_app         U(a = 0.00829, b = 0.02487)              [    0.00 ..      inf],
#    5 |G| k2_true        U(a = 0.0004, b = 0.9025)                [    0.00 ..      inf],
#    6 |G| teff_h         N(μ = 3689.0, σ = 157.0)                 [ 2500.00 .. 12000.00],
#    7 |G| teff_c         U(a = 2500, b = 12000)                   [ 2500.00 .. 12000.00],
#    8 |G| k2_app_tess    U(a = 0.00829, b = 0.02487)              [    0.00 ..      inf],
#    9 |P| q1_tess        N(μ = 0.78909, σ = 0.00374)              [    0.00 ..     1.00],
#   10 |P| q2_tess        N(μ = 0.52221, σ = 0.02536)              [    0.00 ..     1.00],
#   11 |P| q1_g           N(μ = 0.67362, σ = 0.00543)              [    0.00 ..     1.00],
#   12 |P| q2_g           N(μ = 0.54639, σ = 0.02804)              [    0.00 ..     1.00],
#   13 |P| q1_r           N(μ = 0.69751, σ = 0.00506)              [    0.00 ..     1.00],
#   14 |P| q2_r           N(μ = 0.51909, σ = 0.02906)              [    0.00 ..     1.00],
#   15 |P| q1_i           N(μ = 0.77258, σ = 0.00345)              [    0.00 ..     1.00],
#   16 |P| q2_i           N(μ = 0.56593, σ = 0.03631)              [    0.00 ..     1.00],
#   17 |P| q1_z_s         N(μ = 0.81283, σ = 0.00384)              [    0.00 ..     1.00],
#   18 |P| q2_z_s         N(μ = 0.56835, σ = 0.04474)              [    0.00 ..     1.00],
#   19 |L| wn_loge_0      U(a = -4, b = 0)                         [    -inf ..      inf],
#   20 |L| wn_loge_1      U(a = -4, b = 0)                         [    -inf ..      inf],
#   21 |L| wn_loge_2      U(a = -4, b = 0)                         [    -inf ..      inf],
#   22 |L| wn_loge_3      U(a = -4, b = 0)                         [    -inf ..      inf],
#   23 |L| wn_loge_4      U(a = -4, b = 0)                         [    -inf ..      inf],
#   24 |L| wn_loge_5      U(a = -4, b = 0)                         [    -inf ..      inf],
#   25 |L| wn_loge_6      U(a = -4, b = 0)                         [    -inf ..      inf],
#   26 |L| wn_loge_7      U(a = -4, b = 0)                         [    -inf ..      inf],
#   27 |L| wn_loge_8      U(a = -4, b = 0)                         [    -inf ..      inf],
#   28 |L| lm_i__0        N(μ = 1.0, σ = 0.005731812886104185)     [    -inf ..      inf],
#   29 |L| lm_i__0        N(μ = 1.0, σ = 0.006315931083996217)     [    -inf ..      inf],
#   30 |L| lm_i__0        N(μ = 1.0, σ = 0.0066921321961733015)    [    -inf ..      inf],
#   31 |L| lm_i__0        N(μ = 1.0, σ = 0.005527114085477326)     [    -inf ..      inf],
#   32 |L| lm_i__0        N(μ = 1.0, σ = 0.007468747552069094)     [    -inf ..      inf],
#   33 |L| lm_i__0        N(μ = 1.0, σ = 0.009191194541795488)     [    -inf ..      inf],
#   34 |L| lm_i__0        N(μ = 1.0, σ = 0.008576091494669142)     [    -inf ..      inf],
#   35 |L| lm_i__0        N(μ = 1.0, σ = 0.0076441628873117964)    [    -inf ..      inf],
#   36 |L| lm_i__0        N(μ = 1.0, σ = 0.00824910220390101)      [    -inf ..      inf]]

# %%
lpf.optimize_global(2000, npop=100)
# Out:
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# Global optimisation:   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
lpf.plot_folded_tess_transit(plot_model=True, plot_binned=False, figsize=(13,5));

# %%
lpf.plot_gb_transits(figsize=(13,5));

# %%
lpf.sample_mcmc(1500, 50, 3)
# Out:
# MCMC sampling:   0%|          | 0/3 [00:00<?, ?it/s]
# Run 1/3:   0%|          | 0/1500 [00:00<?, ?it/s]
# Run 2/3:   0%|          | 0/1500 [00:00<?, ?it/s]
# Run 3/3:   0%|          | 0/1500 [00:00<?, ?it/s]

# %%
lpf.plot_joint_marginals();
